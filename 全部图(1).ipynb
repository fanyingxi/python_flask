# %%
import pandas as pd
import folium
import plotly.offline as py
import cufflinks as cf
import numpy as np
import plotly.graph_objs as go

# %%
N = pd.read_csv('forbes.csv',encoding="utf8",\
                 keep_default_na=False, na_values='na_rep')
N.head()
# Out:
#    排名              英文姓名        中文姓名 财富（十亿美元）       行业   国籍       x      y
# 0   1        Jeff Bezos      杰夫·贝索斯      131      亚马逊   美国   45.04  40.07
# 1   2        Bill Gates       比尔·盖茨     96.5       微软   美国   45.04  40.07
# 2   3    Warren Buffett      沃伦·巴菲特     82.5  伯克希尔哈撒韦   美国   45.04  40.07
# 3   4   Bernard Arnault     伯纳德·阿诺特       76      奢侈品   法国    2.21  46.23
# 4   5  Carlos Slim Helu  卡洛斯·斯利姆·埃卢       64       电信  墨西哥 -102.55  23.63

# %%
# 显示全部富豪所在国籍的地图
latitude = 39.92
longitude = 116.46

from folium import plugins

# let's start again with a clean copy of the map of San Francisco
san_map = folium.Map(location = [latitude, longitude], zoom_start = 4)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(san_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(N.y, N.x, N.中文姓名):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# add incidents to map
san_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 显示全部富豪所在国籍的表
limit = 2152
data = N.iloc[0:limit, :]
# Count crime numbers in each neighborhood
disdata0 = pd.DataFrame(data['国籍'].value_counts())
disdata0.reset_index(inplace=True)
disdata0.rename(columns={'index':'国家','PdDistrict':'Count'},inplace=True)
disdata0
# Out:
#          国家   国籍
# 0        美国  607
# 1      中国内地  324
# 2        德国  114
# 3        印度  106
# 4       俄罗斯   98
# 5      中国香港   71
# 6        巴西   58
# 7        英国   55
# 8       加拿大   45
# 9        法国   41
# 10     中国台湾   40
# 11       韩国   40
# 12     澳大利亚   36
# 13      意大利   35
# 14       瑞典   33
# 15       瑞士   33
# 16       日本   32
# 17       泰国   31
# 18      西班牙   29
# 19      土耳其   25
# 20      新加坡   22
# 21      以色列   21
# 22       印尼   21
# 23      菲律宾   17
# 24      墨西哥   17
# 25       挪威   15
# 26     马来西亚   13
# 27       智利   11
# 28       丹麦   10
# 29       荷兰   10
# ..      ...  ...
# 41      阿根廷    5
# 42       南非    5
# 43    哈萨克斯坦    5
# 44       越南    4
# 45     尼日利亚    4
# 46       希腊    4
# 47      摩纳哥    4
# 48      比利时    3
# 49     哥伦比亚    3
# 50      新西兰    2
# 51  圣基茨和尼维斯    2
# 52      摩洛哥    2
# 53      匈牙利    2
# 54       阿曼    2
# 55     斯洛伐克    2
# 56     委内瑞拉    2
# 57     罗马尼亚    1
# 58      葡萄牙    1
# 59    阿尔及利亚    1
# 60     中国澳门    1
# ...

# %%
# 显示前20富豪所在国籍的表
limit = 20
data = N.iloc[0:limit, :]
# Count crime numbers in each neighborhood
disdata1 = pd.DataFrame(data['国籍'].value_counts())
disdata1.reset_index(inplace=True)
disdata1.rename(columns={'index':'国家','PdDistrict':'Count'},inplace=True)
disdata1
# Out:
#      国家  国籍
# 0    美国  14
# 1    法国   2
# 2    印度   1
# 3  中国内地   1
# 4   墨西哥   1
# 5   西班牙   1

# %%
# 显示前20名富豪所在的国籍的地图
latitude = 39.92
longitude = 116.46

from folium import plugins

# let's start again with a clean copy of the map of San Francisco
san_map = folium.Map(location = [latitude, longitude], zoom_start = 4)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(san_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(data.y, data.x, N.中文姓名):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# add incidents to map
san_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 显示前100富豪所在国籍的表
limit = 100
data = N.iloc[0:limit, :]
# Count crime numbers in each neighborhood
disdata2 = pd.DataFrame(data['国籍'].value_counts())
disdata2.reset_index(inplace=True)
disdata2.rename(columns={'index':'国家','PdDistrict':'Count'},inplace=True)
disdata2
# Out:
#        国家  国籍
# 0      美国  32
# 1    中国内地  11
# 2      德国   9
# 3     俄罗斯   8
# 4      法国   6
# 5    中国香港   6
# 6      印度   4
# 7      日本   3
# 8     意大利   2
# 9      印尼   2
# 10     泰国   2
# 11     巴西   2
# 12    墨西哥   2
# 13     瑞典   1
# 14  捷克共和国   1
# 15    奥地利   1
# 16   澳大利亚   1
# 17     荷兰   1
# 18    西班牙   1
# 19    加拿大   1
# 20     英国   1
# 21     智利   1
# 22    爱尔兰   1
# 23     韩国   1

# %%
# 显示前100名富豪所在的国籍的地图
latitude = 39.92
longitude = 116.46

from folium import plugins

# let's start again with a clean copy of the map of San Francisco
san_map = folium.Map(location = [latitude, longitude], zoom_start = 4)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(san_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(d2.y, d2.x, N.中文姓名):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# add incidents to map
san_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 显示前20富豪所在行业的表
limit = 20
data = N.iloc[0:limit, :]

disdata4 = pd.DataFrame(data['行业'].value_counts()) 
disdata4.reset_index(inplace=True)
disdata4.rename(columns={'index':'分类','PdDistrict':'Count'},inplace=True)
disdata4
# Out:
#           分类  行业
# 0        沃尔玛   3
# 1         谷歌   2
# 2         微软   2
# 3       科氏工业   2
# 4         电信   1
# 5       Zara   1
# 6      石化,油气   1
# 7         彭博   1
# 8        欧莱雅   1
# 9       社交媒体   1
# 10       奢侈品   1
# 11       亚马逊   1
# 12   伯克希尔哈撒韦   1
# 13  Facebook   1
# 14        软件   1

# %%
# 显示前20富豪所在行业的柱形图
df1=disdata4[['分类','行业']].sort_values(['行业'],ascending=[0])
data = [go.Bar(x=df1['分类'],y=df1['行业'])]
py.offline.plot(data,filename = '行业（20）.html')

http://127.0.0.1:8000/
# Out:
# '行业（20）.html'

# %%
# 显示前100富豪所在行业的柱形图
df1=disdata5[['分类','行业']].sort_values(['行业'],ascending=[0])
data = [go.Bar(x=df1['分类'],y=df1['行业'])]
py.offline.plot(data,filename = '行业（100）.html')
# Out:
# '行业（100）.html'

# %%
# 显示全部富豪所在行业的表
limit = 2152
data = N.iloc[0:limit, :]

# Count crime numbers in each neighborhood
disdata6 = pd.DataFrame(data['行业'].value_counts()) #GB是指自然保护区类型与级别划分原则
disdata6.reset_index(inplace=True)
disdata6.rename(columns={'index':'分类','PdDistrict':'Count'},inplace=True)
disdata6
# Out:
#            分类   行业
# 0         房地产  186
# 1       多元化经营   97
# 2          投资   89
# 3          制药   69
# 4        对冲基金   44
# 5          零售   43
# 6          软件   35
# 7         银行业   33
# 8         消费品   32
# 9        私募股权   22
# 10         金融   20
# 11         化工   19
# 12       医疗设备   18
# 13      汽车零部件   17
# 14         电信   16
# 15       资金管理   16
# 16         矿业   15
# 17         制造   14
# 18         媒体   14
# 19         电商   14
# 20         钢铁   14
# 21         嘉吉   14
# 22         电子   14
# 23         博彩   12
# 24       建筑施工   12
# 25      酒店,投资   12
# 26       时尚零售   11
# 27         鞋业   11
# 28         药店   10
# 29         创投   10
# ..        ...  ...
# 666      投资研究    1
# 667     能源,体育    1
# 668        玻璃    1
# 669  矿业,金属,机械    1
# 670        采购    1
# 671      监控设备    1
# 672        激光    1
# 673      漫威漫画    1
# 674      课后补习    1
# 675      数字广告    1
# 676       机器人    1
# 677      住宅建造    1
# 678    酒精,房地产    1
# 679        维珍    1
# 680     云存储服务    1
# ...

# %%
# 显示全部富豪所在行业的柱形图
df1=disdata6[['分类','行业']].sort_values(['行业'],ascending=[0])
data = [go.Bar(x=df1['分类'],y=df1['行业'])]
py.offline.plot(data,filename = '行业（全部）.html')
# Out:
# '行业（全部）.html'
