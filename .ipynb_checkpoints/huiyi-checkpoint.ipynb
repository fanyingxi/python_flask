# %%
from pyecharts import options as opts
from pyecharts.charts import Map,Tab
from pyecharts.globals import ChartType, SymbolType
import pandas as pd

# %%
df=pd.read_csv('自杀率.csv')
df
# Out:
#                                                     国家  男性自杀率  女性自杀率  总自杀率
# 0                                          Afghanistan   10.6    2.1   6.4
# 1                                              Albania    7.0    4.3   5.6
# 2                                              Algeria    4.9    1.8   3.3
# 3                                               Angola   14.0    4.6   8.9
# 4                                  Antigua and Barbuda    0.0    0.9   0.5
# 5                                            Argentina   15.0    3.5   9.1
# 6                                              Armenia   10.1    2.0   5.7
# 7                                            Australia   17.4    6.0  11.7
# 8                                              Austria   17.5    5.7  11.4
# 9                                           Azerbaijan    4.3    1.0   2.6
# 10                                             Bahamas    2.8    0.5   1.6
# ...

# %%
自杀率 = list(zip(list(df.国家),list(df.总自杀率)))

# %%
def map_world() -> Map:
    c = (
        Map()
        .add("2016年总自杀率（每10万人）", [list(z) for z in zip(df["国家"], df["总自杀率"])], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="2016年总自杀率"),
            visualmap_opts=opts.VisualMapOpts(min_=0,max_=30),
        )
    )
    return c
map_world().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="2beb45a318564edbb11a77137e6fb531" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_2beb45a318564edbb11a77137e6fb531 = echarts.init(
#                     document.getElementById('2beb45a318564edbb11a77137e6fb531'), 'white', {renderer: 'canvas'});
#                 var option_2beb45a318564edbb11a77137e6fb531 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
自杀率二 = list(zip(list(df.国家),list(df.男性自杀率)))

# %%
def map_world1() -> Map:
    c = (
        Map()
        .add("2016年男性自杀率（每10万人）", [list(z) for z in zip(df["国家"], df["男性自杀率"])], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="2016年男性自杀率"),
            visualmap_opts=opts.VisualMapOpts(min_=0,max_=30),
        )
    )
    return c
map_world1().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="1bc54cf77b8a4583a4644df93f6247cf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_1bc54cf77b8a4583a4644df93f6247cf = echarts.init(
#                     document.getElementById('1bc54cf77b8a4583a4644df93f6247cf'), 'white', {renderer: 'canvas'});
#                 var option_1bc54cf77b8a4583a4644df93f6247cf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
自杀率三 = list(zip(list(df.国家),list(df.女性自杀率)))

# %%
def map_world2() -> Map:
    c = (
        Map()
        .add("2016年女性性自杀率（每10万人）", [list(z) for z in zip(df["国家"], df["女性自杀率"])], "world")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="2016年女性自杀率"),
            visualmap_opts=opts.VisualMapOpts(min_=0,max_=30),
        )
    )
    return c
map_world2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="6094e5d49b9d4132980b181d75dec85e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_6094e5d49b9d4132980b181d75dec85e = echarts.init(
#                     document.getElementById('6094e5d49b9d4132980b181d75dec85e'), 'white', {renderer: 'canvas'});
#                 var option_6094e5d49b9d4132980b181d75dec85e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
tab = Tab()
tab.add(map_world(), "2016年总自杀率")
tab.add(map_world1(), "2016年男性自杀率")
tab.add(map_world2(), "2016年女性自杀率")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
# ...

# %% [markdown]
# #### 数据故事：
# 我从世界健康组织拿到了2016年各国自杀率的数据。通过在地图上的可视化呈现可知：
#
#
# 1.  世界上自杀率较高的国家分布于非洲中部，东欧内陆国家及一些亚洲发展中国家，如印度等。
# 2，对比总体男/女自杀率而言，男性自杀率普遍高于女性。
# 3.同时，总自杀率较高的国家与女性自杀率的国家重合程度较高。
